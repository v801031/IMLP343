# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# %% [markdown]
# ##  尋找matplotlib中可用字體
# 註：需知道中文字體的英文名稱

# %%
import matplotlib
from matplotlib.font_manager import FontProperties
[f.name for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['STIXSizeTwoSym',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'cmss10',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'cmr10',
#  'DejaVu Sans Display',
#  'DejaVu Sans',
#  'cmmi10',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Serif Display',
#  'cmtt10',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'cmsy10',
#  'DejaVu Sans',
#  'cmb10',
#  'STIXSizeFiveSym',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'cmex10',
#  'Sukhumvit Set',
#  'lihsianti',
#  'Noto Sans Armenian',
#  'Arial',
#  'Noto Sans Marchen',
#  'Noto Sans Gothic',
#  'Arial',
#  'Marion',
#  'Noto Sans Ogham',
#  'Noto Sans Tagalog',
#  'Wingdings',
#  'Taiwan icon',
#  '.New York',
#  'AppleGothic',
#  'STIXIntegralsUpSm',
#  'Charter',
#  'Euphemia UCAS',
#  'Verdana',
#  'Noto Sans Adlam',
#  'Hoefler Text',
#  'Courier New',
#  'Noto Sans PhagsPa',
#  'jf-jinxuan-fresh2.2',
#  'Gurmukhi Sangam MN',
#  '.Arabic UI Display',
#  'Arial',
#  'Andale Mono',
#  'Noto Sans Hatran',
#  'Tahoma',
#  'Verdana',
#  'Noto Sans Lydian',
#  'Noto Sans Inscriptional Pahlavi',
#  'Corsiva Hebrew',
#  'Academy Engraved LET',
#  'STIXGeneral',
#  'Superclarendon',
#  'Thonburi',
#  'STIXSizeTwoSym',
#  'Noto Sans Old Persian',
#  'STIXNonUnicode',
#  'lihsianti',
#  'Noto Sans Khojki',
#  'Noto Sans Bhaiksuki',
#  'Noto Sans Sundanese',
#  'Chalkboard SE',
#  'Arial Narrow',
#  'PingFang HK',
#  'Noto Sans Lisu',
#  'Noto Sans Phoenician',
#  'Silom',
#  'Noto Sans Elbasan',
#  'Noto Sans Buginese',
#  'Apple Braille',
#  'Noto Sans Duployan',
#  'Heiti TC',
#  'Trebuchet MS',
#  'Myanmar Sangam MN',
#  'Hiragino Sans',
#  'Noto Sans Mende Kikakui',
#  'Noto Serif Myanmar',
#  'Noto Sans Samaritan',
#  'burnfont-1.1',
#  'Big Caslon',
#  'Sana',
#  'Kannada MN',
#  'Apple Symbols',
#  'Noto Sans Mongolian',
#  'Didot',
#  'jf-openhuninn-1.0',
#  'Noto Sans Old North Arabian',
#  'Baghdad',
#  'Hiragino Sans',
#  'Noto Sans Osage',
#  'Kohinoor Devanagari',
#  'Apple Chancery',
#  '.Aqua Kana',
#  'Farah',
#  'Arial Unicode MS',
#  'Sinhala MN',
#  'Lucida Grande',
#  'Noto Sans Pau Cin Hau',
#  '.SF Compact',
#  'STIXGeneral',
#  'Noto Sans Meroitic',
#  'Noto Serif Ahom',
#  'STIXGeneral',
#  'STIXIntegralsUp',
#  'STIXIntegralsUp',
#  'STIXIntegralsD',
#  'Noto Sans Nabataean',
#  'Lao Sangam MN',
#  'KufiStandardGK',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'Al Nile',
#  'Noteworthy',
#  'Avenir Next',
#  'Microsoft Sans Serif',
#  'Al Tarikh',
#  'Cochin',
#  'STIXSizeFourSym',
#  'Muna',
#  'STIXSizeThreeSym',
#  'Devanagari MT',
#  'Comic Sans MS',
#  '.SF NS Mono',
#  'Baskerville',
#  'Noto Sans Kaithi',
#  'STIXIntegralsSm',
#  'Krungthep',
#  'STIXGeneral',
#  'Iowan Old Style',
#  'Trattatello',
#  'Apple Braille',
#  'Noto Sans Glagolitic',
#  'Noto Serif Balinese',
#  'Zapfino',
#  'Noto Sans Bassa Vah',
#  'InaiMathi',
#  'lihsianti',
#  'Arial',
#  'Hiragino Sans',
#  'Telugu MN',
#  '.New York',
#  'Seravek',
#  'Arial Narrow',
#  'Noto Sans Hanunoo',
#  'Geeza Pro',
#  'STIXIntegralsUpD',
#  'Noto Sans Batak',
#  'Noto Sans Meetei Mayek',
#  'STIXNonUnicode',
#  'Noto Sans Lepcha',
#  'Noto Sans Sora Sompeng',
#  'Noto Sans Mandaic',
#  'Shree Devanagari 714',
#  'Apple Braille',
#  'Mshtakan',
#  'Noto Sans Syloti Nagri',
#  'Noto Sans Osmanya',
#  'Herculanum',
#  'Kannada Sangam MN',
#  'Telugu Sangam MN',
#  'Hiragino Maru Gothic Pro',
#  'Noto Sans Tifinagh',
#  'Arial Narrow',
#  'STIXIntegralsUpD',
#  'Optima',
#  'Sinhala Sangam MN',
#  'Noto Sans Newa',
#  'PT Serif',
#  'Times New Roman',
#  'STIXNonUnicode',
#  'Bodoni 72 Smallcaps',
#  'jf-jinxuan-fresh2.2',
#  'Noto Sans Javanese',
#  'Verdana',
#  'Noto Sans Kayah Li',
#  'Hiragino Sans',
#  'Bangla Sangam MN',
#  'STIXIntegralsSm',
#  'Noto Sans Tagbanwa',
#  'Noto Sans New Tai Lue',
#  'Gujarati Sangam MN',
#  'American Typewriter',
#  'Hiragino Sans',
#  'Papyrus',
#  '.Keyboard',
#  'Noto Sans Tirhuta',
#  'Luminari',
#  'Gurmukhi MN',
#  '.SF NS Rounded',
#  'Diwan Thuluth',
#  'DIN Alternate',
#  'Noto Sans Thaana',
#  'Kailasa',
#  'Arial Narrow',
#  'Noto Sans Takri',
#  'Trebuchet MS',
#  'Noto Sans Palmyrene',
#  'jf-jinxuan-fresh2.2',
#  'Bangla MN',
#  'Noto Nastaliq Urdu',
#  'Noto Sans Linear A',
#  'Noto Sans Hanifi Rohingya',
#  'Wingdings 3',
#  'Zapf Dingbats',
#  'Mishafi',
#  'Noto Sans Cypriot',
#  'Raanana',
#  'Nadeem',
#  'Hiragino Sans',
#  'STIXSizeOneSym',
#  'Noto Sans Runic',
#  'Noto Sans Wancho',
#  'STIXIntegralsUpSm',
#  'Chalkduster',
#  'Noto Sans Vai',
#  'Noto Sans Old Hungarian',
#  'Hiragino Sans GB',
#  'burnfont-1.0',
#  'Webdings',
#  'Noto Sans Imperial Aramaic',
#  'Mukta Mahee',
#  'System Font',
#  'Noto Sans Tai Tham',
#  '.SF NS Mono',
#  'Helvetica',
#  'Apple Braille',
#  'Malayalam MN',
#  'Galvji',
#  'Tamil Sangam MN',
#  'Noto Sans Mahajani',
#  'Noto Sans Tai Le',
#  'Copperplate',
#  'Noto Sans Limbu',
#  'Gujarati MT',
#  'Symbol',
#  'Kohinoor Gujarati',
#  'Noto Sans Pahawh Hmong',
#  'Heiti TC',
#  'Avenir Next Condensed',
#  'Snell Roundhand',
#  'Times New Roman',
#  'Noto Sans Linear B',
#  'ITF Devanagari',
#  'Bradley Hand',
#  'Brush Script MT',
#  'Noto Sans Manichaean',
#  'Noto Sans Cuneiform',
#  'Damascus',
#  'Apple SD Gothic Neo',
#  'Noto Sans Brahmi',
#  'Noto Sans Psalter Pahlavi',
#  'Impact',
#  'Noto Sans Modi',
#  'Noto Sans Old Permic',
#  'Noto Sans Avestan',
#  'Arial Rounded MT Bold',
#  'Khmer Sangam MN',
#  'Tahoma',
#  'New Peninim MT',
#  'Ayuthaya',
#  'Kokonor',
#  'Noto Sans Myanmar',
#  'Khmer MN',
#  'Noto Sans Carian',
#  'Arial Black',
#  'Noto Sans Old Italic',
#  'Hiragino Sans',
#  'Gurmukhi MT',
#  'Noto Sans Rejang',
#  'Waseem',
#  'Gill Sans',
#  '.Arabic UI Text',
#  'DIN Condensed',
#  'Georgia',
#  'Sathu',
#  'Hiragino Sans',
#  'Arial Unicode MS',
#  'Tamil MN',
#  'Rockwell',
#  'Kohinoor Bangla',
#  'DecoType Naskh',
#  'Noto Sans NKo',
#  'Courier New',
#  'Devanagari Sangam MN',
#  'Noto Sans Lycian',
#  'STIXSizeThreeSym',
#  'AppleMyungjo',
#  'Diwan Kufi',
#  'Noto Sans Tai Viet',
#  'Times',
#  'Trebuchet MS',
#  'lihsianti',
#  'Al Bayan',
#  'STIXIntegralsD',
#  'Georgia',
#  'Noto Sans Kannada',
#  'Trebuchet MS',
#  'Noto Sans Ugaritic',
#  'Apple Braille',
#  'Noto Sans Siddham',
#  'Noto Sans Inscriptional Parthian',
#  'Oriya MN',
#  'Noto Sans Caucasian Albanian',
#  'Georgia',
#  'Skia',
#  'Hiragino Mincho ProN',
#  'PT Serif Caption',
#  'SignPainter',
#  'Kefa',
#  'Noto Sans Bamum',
#  'Noto Sans Khudawadi',
#  'Oriya Sangam MN',
#  'Menlo',
#  'Farisi',
#  'Savoye LET',
#  'Bodoni 72 Oldstyle',
#  'Beirut',
#  'Hiragino Sans',
#  '.SF Compact',
#  'Phosphate',
#  'Noto Sans Kharoshthi',
#  'Noto Sans Shavian',
#  'Hoefler Text',
#  'STIXVariants',
#  'Bodoni 72',
#  'STIXSizeFourSym',
#  'Mishafi Gold',
#  'Noto Sans Saurashtra',
#  'Noto Sans Oriya',
#  'Noto Sans Sharada',
#  'Lao MN',
#  'System Font',
#  'Courier New',
#  'Noto Sans Old Turkic',
#  'Myanmar MN',
#  'Arial Hebrew',
#  'Helvetica Neue',
#  'Times New Roman',
#  'Noto Sans Buhid',
#  'Plantagenet Cherokee',
#  'Bodoni Ornaments',
#  'Verdana',
#  'Party LET',
#  'Courier New',
#  'Noto Sans Miao',
#  'Athelas',
#  'PT Sans',
#  'Noto Sans Multani',
#  'Songti SC',
#  'Noto Sans Chakma',
#  'STIXSizeFiveSym',
#  'Comic Sans MS',
#  'Noto Sans Mro',
#  'Noto Sans Egyptian Hieroglyphs',
#  'Chalkboard',
#  'Avenir',
#  'STIXSizeOneSym',
#  'Noto Sans Coptic',
#  'Hiragino Sans',
#  'Kohinoor Telugu',
#  'Times New Roman',
#  'Georgia',
#  'Futura',
#  '.SF Compact Rounded',
#  'Wingdings 2',
#  'Noto Sans Old South Arabian',
#  'Noto Sans Cham',
#  'Noto Sans Yi',
#  'STIXVariants',
#  'Noto Sans Syriac',
#  'Marker Felt',
#  'Malayalam Sangam MN',
#  'Noto Sans Ol Chiki',
#  'Noto Sans Warang Citi',
#  'Palatino',
#  'TeamViewer13',
#  'PT Mono']

# %% [markdown]
# ## 測試中文字體Notes:
# ### Mac可用字體：SimHei
# ### Windows 7可用字體：Microsoft YaHei
# ### Windows 10 可用字體：Microsoft JhengHei、DFKai-SB

# %% [markdown]
# # 方法一：更改 plt.rcParams['font.sans-serif'] 設定
# ## Matplotlib example

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
plt.rcParams['font.sans-serif'] = ['jf-jinxuan-fresh2.2'] 

plt.plot((1,2,3),(4,3,-1))
plt.title("聲量圖")
plt.ylabel("文章數量")
plt.xlabel("品牌名稱") 
plt.show()

# %% [markdown]
# ## Seaborn example

# %%
#from matplotlib.font_manager import FontProperties
import seaborn as sns
sns.set(font=['sans-serif'])
sns.set_style("whitegrid",{"font.sans-serif":['jf-jinxuan-fresh2.2']})
cities_counter = [('好棒', 285), ('給我', 225), ('不要', 163), ('細柔', 136), ('吃飯', 130), ('小小', 124), ('深圳', 88), ('温州', 67), ('小知', 66), ('大之', 45)]
sns.set_color_codes("pastel")
sns.barplot(x=[k for k, _ in cities_counter[:10]], y=[v for _, v in cities_counter[:10]])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 方法二：更改 plt.rcParams['font.family'] 設定

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(6,4))
x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.rcParams['font.family']='jf-jinxuan-fresh2.2' #使用中文字體（黑體）

plt.bar(x,y,align='center')
plt.title('中文標題') #標題名稱
plt.xlabel('X軸') #X軸名稱
plt.ylabel('Y軸') #Y軸名稱
plt.xticks(x, ['刻度A','刻度B','刻度C','刻度D','刻度E']) #X軸刻度名稱

plt.show()

# %% [markdown]
# # 方法三：每次作圖使用特定字體

# %%
font1 = {'fontname':'jf-jinxuan-fresh2.2'}
font2 = {'fontname':'jf-jinxuan-fresh2.2'}
font3 = {'fontname':'jf-jinxuan-fresh2.2'}

plt.bar(x,y,align='center')
plt.title('瀨戶字體標題',**font1, fontsize=18) #標題名稱
plt.xlabel('新宋字體X軸',**font2, fontsize=18) #X軸名稱
plt.ylabel('黑體Y軸',**font3, fontsize=18) #Y軸名稱
plt.show()

# %% [markdown]
# # 方法四、自訂字體型式
# ### 下載`.ttf`字體檔，直接指定字體路徑

# %%
from matplotlib.font_manager import FontProperties
font = FontProperties(fname='data/微軟正黑體.ttf')

plt.bar((1,2,3),(4,3,-1),align='center')
plt.title('微軟正黑體標題',fontproperties=font, fontsize=18) #標題名稱
plt.xlabel('微軟正黑體X軸',fontproperties=font, fontsize=18) #X軸名稱
plt.ylabel('微軟正黑體Y軸',fontproperties=font, fontsize=18) #Y軸名稱
plt.show()
